# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
from nba_api.stats.endpoints import playergamelog, leaguedashteamstats
from nba_api.stats.static import players, teams
from _team_stat_helpers import load_team_stats, get_t__team_rolling_avg, get_team_rolling_avg, get_latest_team_stat, get_def_vs_avg_scale, get_team_stats_df
from __feature_helpers import enrich_with_adv_player_stats, enrich_current_game_with_adv_stats
#load_team_stats("merged_player_team_adv_stats_2024-25.csv")
# Out:
# [✓] Loaded team stats with 34190 rows.

# %%
load_team_stats("merged_player_team_adv_stats_2024-25.csv")
# Out:
# [✓] Loaded team stats with 34190 rows.

# %%
class FeatureBuilder:
    def __init__(self, players_by_team, season='2024-25', rolling_window=5):
        self.players_by_team = players_by_team
        self.season = season
        self.rolling_window = rolling_window
        self.all_player_ids = self._build_player_lookup()
        self.team_abbrev_to_id = self._build_team_abbrev_to_id()
        self.team_advanced_stats = self._fetch_team_advanced_stats()
    
    def _build_player_lookup(self):
        # Get full list of NBA players and map names to IDs
        player_list = players.get_players()
        return {p['full_name']: p['id'] for p in player_list}
    
    def _build_team_abbrev_to_id(self):
        return {t['abbreviation']: t['id'] for t in teams.get_teams()}

    def _fetch_team_advanced_stats(self):
        
        """
        Loads precomputed team stats (already merged with player data) 
        from the CSV-backed global _team_stats_df.
        Returns a dict: {TEAM_ID: {col1: val1, col2: val2, ...}}
        """
        _df = get_team_stats_df()

        if _df is None:
            raise RuntimeError("Team stats not loaded. Call load_team_stats() before initializing FeatureBuilder.")

        _df.columns = _df.columns.str.strip()  # strip whitespace

        # Log column names
        #print("[Debug] Columns in loaded team stats:", _df.columns.tolist())

        # Confirm TEAM_ID is in columns
        if 'TEAM_ID' not in _df.columns:
            raise KeyError("[!] 'TEAM_ID' is missing from loaded team stats. Check CSV or column names.")

        # Drop duplicates and sort
        team_stats_df = _df.drop_duplicates(subset=['GAME_ID', 'TEAM_ID']).copy()
        team_stats_df = team_stats_df.sort_values('GAME_DATE')

        relevant_cols = [
            'TEAM_ID',
            'TEAM_PACE', 'TEAM_OFF_RATING', 'TEAM_AST_PCT',
            'TEAM_E_OFF_RATING', 'TEAM_E_DEF_RATING', 'TEAM_REB_PCT'
        ]
        missing_cols = [col for col in relevant_cols if col not in team_stats_df.columns]
        if missing_cols:
            #print(f"[!] Missing team stat columns: {missing_cols}")
            return {}

        try:
            # Get latest row per team
            latest_by_team = team_stats_df.groupby('TEAM_ID').last()
            return latest_by_team[[col for col in relevant_cols if col != 'TEAM_ID']].to_dict(orient='index')

        except Exception as e:
            print(f"[!] Error building team stats from merged CSV: {e}")
            return {}

    def fetch_game_log(self, player_name):
        player_id = self.all_player_ids.get(player_name)
        if not player_id:
            print(f"[!] Player ID not found for {player_name}")
            return pd.DataFrame()
        try:
            gl = playergamelog.PlayerGameLog(player_id=player_id, season=self.season)
            df = gl.get_data_frames()[0]
            df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'], format='%b %d, %Y', errors='coerce')
            df.sort_values('GAME_DATE', inplace=True)
            df.reset_index(drop=True, inplace=True)
            df.rename(columns={'Player_ID': 'PLAYER_ID'}, inplace=True)
            return df
        except Exception as e:
            print(f"[!] Error fetching log for {player_name}: {e}")
            return pd.DataFrame()
    
    def generate_features(self):
        all_feature_rows = []
        for team, player_list in self.players_by_team.items():
            print(f"\n[+] Processing team: {team}")
            for player_name in player_list:
                print(f"    - Fetching: {player_name}")
                game_log = self.fetch_game_log(player_name)
                if game_log.empty or len(game_log) < self.rolling_window:
                    print(f"      Skipping {player_name}, not enough data.")
                    continue
                
                features = self._calculate_rolling_features(game_log, player_name)
                all_feature_rows.append(features)
                time.sleep(0.6)  # Prevent NBA API timeout
                
        if all_feature_rows:
            return pd.concat(all_feature_rows, ignore_index=True)
        else:
            return pd.DataFrame()

    def _calculate_rolling_features(self, df, player_name):
        feature_rows = []

        def parse_minutes(min_val):
            try:
                if isinstance(min_val, str) and ':' in min_val:
                    parts = min_val.split(':')
                    return int(parts[0]) + int(parts[1]) / 60
                return float(min_val)
            except Exception as e:
                print(f"parse_minutes() failed for: {min_val} with error: {e}")
                return 0

        for i in range(self.rolling_window, len(df)):
            current_game = df.iloc[i].copy()
            past_games = df.iloc[i - self.rolling_window:i].copy()

            try:
                current_game = enrich_current_game_with_adv_stats(current_game)
            except Exception as e:
                print(f"[!] Failed to enrich current_game: {e}")
            try:
                past_games = enrich_with_adv_player_stats(past_games)
            except Exception as e:
                print(f"[!] Failed to enrich past_games: {e}")

            # Team IDs
            opp_abbrev = current_game['MATCHUP'].split(' ')[-1]
            player_team_abbrev = current_game['MATCHUP'].split(' ')[0]
            opp_team_id = self.team_abbrev_to_id.get(opp_abbrev)
            player_team_id = self.team_abbrev_to_id.get(player_team_abbrev)
            usg_pct_current = current_game.get('USG_PCT', np.nan)

            # Team-level rolling stats
            rolling_opp_def_5g = get_team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_DEF_RATING')
            rolling_opp_blocks_5g = get_t__team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_BLK')
            rolling_opp_steals_5g = get_t__team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_STL')
            rolling_opp_fouls_5g = get_t__team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_PF')
            rolling_opp_ast_pct_5g = get_team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_AST_PCT')
            if np.isnan(rolling_opp_ast_pct_5g):
                rolling_opp_ast_pct_5g = np.nan
            rolling_opp_reb_pct_5g = get_team_rolling_avg(opp_team_id, current_game['GAME_DATE'], 'TEAM_REB_PCT')
            if np.isnan(rolling_opp_reb_pct_5g): 
                rolling_opp_reb_pct_5g = np.nan
            rolling_team_off_5g = get_team_rolling_avg(player_team_id, current_game['GAME_DATE'], 'TEAM_OFF_RATING')
            rolling_team_ast_pct_5g = get_team_rolling_avg(player_team_id, current_game['GAME_DATE'], 'TEAM_AST_PCT')
            rolling_team_reb_pct_5g = get_team_rolling_avg(player_team_id, current_game['GAME_DATE'], 'TEAM_REB_PCT')
            latest_team_e_off_rating = get_latest_team_stat(player_team_id, current_game['GAME_DATE'], 'TEAM_E_OFF_RATING')
            latest_opp_e_def_rating = get_latest_team_stat(opp_team_id, current_game['GAME_DATE'], 'TEAM_E_DEF_RATING')
            if np.isnan(latest_opp_e_def_rating):
                latest_opp_e_def_rating = np.nan

            # Defensive mean helper
            def safe_mean(col): return past_games[col].dropna().mean() if col in past_games.columns else np.nan

            # Rolling player-level stats
            rolling_usg_pct_5G = safe_mean('USG_PCT')
            rolling_e_usg_pct_5G = safe_mean('E_USG_PCT')
            rolling_fg_pct_5G = safe_mean('FG_PCT')
            rolling_fg3_pct_5G = safe_mean('FG3_PCT')
            rolling_fga_5G = safe_mean('FGA')
            rolling_poss_5G = safe_mean('POSS')
            rolling_Team_e_pace_5G = safe_mean('TEAM_E_PACE')
            rolling_ast_pct_5G = safe_mean('AST_PCT')
            rolling_oreb_pct_5G = safe_mean('OREB_PCT')
            rolling_dreb_pct_5G = safe_mean('DREB_PCT')
            rolling_reb_pct_5G = safe_mean('REB_PCT')
            rolling_pts_from_3_5g = safe_mean('PTS_3')
            rolling_pts_from_2_5g = safe_mean('PTS_2')
            rolling_pts_from_ft_5g = safe_mean('PTS_FT')
            rolling_looseball_rec_5g = safe_mean('LOOSE_BALLS_RECOVERED')
            rolling_screen_ast_5g = safe_mean('SCREEN_ASSISTS')
            touches_to_pts_ratio = past_games['PTS'].sum() / max(past_games['TCHS'].sum(), 1)
            transition_pts_pct = past_games['PTS_FB'].sum() / max(past_games['PTS'].sum(), 1)

            # Basic stats
            rolling_pts_avg = past_games['PTS'].mean()
            rolling_std = past_games['PTS'].std()
            rolling_3pm_avg = past_games['FG3M'].mean()
            pts_trend_slope_5G = past_games['PTS'].iloc[-1] - past_games['PTS'].iloc[0]

            # MIN handling
            minutes_list = past_games['MIN'].apply(parse_minutes)
            min_avg = minutes_list.mean()
            last_game_min = parse_minutes(df.iloc[i - 1]['MIN'])
            delta_min_vs_rolling = last_game_min - min_avg if last_game_min and min_avg else np.nan

            # Adjusted projections
            def_rating_scale = get_def_vs_avg_scale(opp_team_id, current_game['GAME_DATE'], stat_col='TEAM_DEF_RATING')
            adjusted_pts_proj_def = rolling_pts_avg * (def_rating_scale if not np.isnan(def_rating_scale) else 1.0)
            adjusted_pts_proj_usg = (rolling_pts_avg * (def_rating_scale if not np.isnan(def_rating_scale) else 1.0)
                * (usg_pct_current if not np.isnan(usg_pct_current) else 1.0))

            # Safe guards for ratios
            fga_safe = max(rolling_fga_5G, 1e-5)
            min_safe = max(min_avg, 1e-5)
            pts_safe = max(rolling_pts_avg, 1e-5)
            three_pm_safe = max(rolling_3pm_avg, 1e-5)

            # Ratios
            shots_per_min = rolling_fga_5G / min_safe
            pts_per_fga = rolling_pts_avg / fga_safe
            pts_per_min = rolling_pts_avg / min_safe
            pts_to_3pm_ratio = rolling_pts_avg / three_pm_safe
            ast_to_poss_ratio = rolling_ast_pct_5G / max(rolling_poss_5G, 1e-5)
            usg_to_poss_ratio = rolling_usg_pct_5G / max(rolling_poss_5G, 1e-5)
            engagement_index = (rolling_usg_pct_5G + rolling_ast_pct_5G + rolling_reb_pct_5G) / max(rolling_Team_e_pace_5G, 1e-5)
            volume_efficiency_ratio = rolling_usg_pct_5G * pts_per_fga

            # More deltas
            delta_pts_vs_rolling = df.iloc[i - 1]['PTS'] - rolling_pts_avg
            if rolling_opp_def_5g is not None and latest_opp_e_def_rating is not None and not np.isnan(rolling_opp_def_5g) and not np.isnan(latest_opp_e_def_rating):
                opp_def_trend_delta = latest_opp_e_def_rating - rolling_opp_def_5g
            else:
                opp_def_trend_delta = np.nan
            delta_fg_pct_vs_avg = current_game['FG_PCT'] / rolling_fg_pct_5G
            delta_fga_vs_rolling = current_game['FGA'] / rolling_fga_5G

            # Flags
            is_volume_shooter = int(rolling_fga_5G >= 15)
            is_trending_up = int(pts_trend_slope_5G > 0)
            is_trending_down = int(pts_trend_slope_5G < 0)
            high_efficiency = int(pts_per_fga >= 1.25)

            # Team pacing
            team_stats = self.team_advanced_stats.get(player_team_id, {})
            opp_stats = self.team_advanced_stats.get(opp_team_id, {})
            team_pace = team_stats.get('TEAM_PACE', np.nan)
            opp_pace = opp_stats.get('TEAM_PACE', np.nan)

            
            start_pos = str(current_game.get('START_POSITION', '')).strip().upper()
            is_valid_start = 1.0 if start_pos in ['C', 'F', 'G'] else 0.0

            # META FEATURES:
            volume_times_efficiency = rolling_fga_5G * pts_per_fga
            usg_min_product = rolling_usg_pct_5G * min_avg
            scoring_touch_ratio = touches_to_pts_ratio * pts_per_min
            volume_efficiency_to_pts = volume_efficiency_ratio * rolling_pts_avg
            adjusted_shot_creation = rolling_fga_5G + rolling_ast_pct_5G


            row ={ 
                'PLAYER_NAME': player_name,
                'PLAYER_ID': current_game['PLAYER_ID'],
                'GAME_DATE': current_game['GAME_DATE'],
                'TEAM_ID': player_team_id,
                'OPP_TEAM_ID': opp_team_id,
                'HOME_AWAY': 0 if '@' in current_game['MATCHUP'] else 1,
                'rolling_pts_avg_5G': rolling_pts_avg,
                'rolling_pts_median_5G': past_games['PTS'].median(),
                'rolling_3pm_avg_5G': rolling_3pm_avg,
                'rolling_3pm_median_5G': past_games['FG3M'].median(),
                'rolling_min_avg_5G': min_avg,
                'rolling_std_pts_5G': rolling_std,
                'pts_consistency_score': rolling_pts_avg / (rolling_std + 1e-5),
                'rest_days': (current_game['GAME_DATE'] - df.iloc[i - 1]['GAME_DATE']).days,
                'is_b2b': int((current_game['GAME_DATE'] - df.iloc[i - 1]['GAME_DATE']).days == 1),
                'rolling_opp_def_rating_5G': rolling_opp_def_5g,
                'rolling_opp_ast_pct_5G': rolling_opp_ast_pct_5g,
                'rolling_opp_blocks_5g': rolling_opp_blocks_5g,
                'rolling_opp_steals_5g': rolling_opp_steals_5g,
                'rolling_opp_fouls_5g': rolling_opp_fouls_5g,
                'rolling_team_off_rating_5G': rolling_team_off_5g,
                'rolling_team_reb_pct_5G': rolling_team_reb_pct_5g,
                'rolling_team_ast_pct_5G': rolling_team_ast_pct_5g,
                'rolling_opp_reb_pct_5G': rolling_opp_reb_pct_5g,
                'latest_team_e_off_rating': latest_team_e_off_rating,
                'latest_opp_e_def_rating': latest_opp_e_def_rating,
                'adjusted_pts_proj_def': adjusted_pts_proj_def,
                'adjusted_pts_proj_usg': adjusted_pts_proj_usg,
                'rolling_usg_pct_5G': rolling_usg_pct_5G,
                'rolling_e_usg_pct_5G': rolling_e_usg_pct_5G,
                'rolling_fg_pct_5G': rolling_fg_pct_5G,
                'rolling_fg3_pct_5G': rolling_fg3_pct_5G,
                'rolling_fga_5G': rolling_fga_5G,
                'delta_pts_vs_rolling': delta_pts_vs_rolling,
                'delta_min_vs_rolling': delta_min_vs_rolling,
                'delta_fga_vs_rolling': delta_fga_vs_rolling,
                'opp_def_trend_delta': opp_def_trend_delta,
                'fg_pct_vs_avg_delta': delta_fg_pct_vs_avg,
                'shots_per_min': shots_per_min,
                'pts_per_fga': pts_per_fga,
                'pts_per_min': pts_per_min,
                'team_pace': team_pace,
                'opp_pace': opp_pace,
                'pts_to_3pm_ratio': pts_to_3pm_ratio,
                'pts_trend_slope_5G': pts_trend_slope_5G,
                'is_volume_shooter': is_volume_shooter,
                'is_trending_up': is_trending_up,
                'is_trending_down': is_trending_down,
                'high_efficiency': high_efficiency,
                'rolling_ast_pct_5G': rolling_ast_pct_5G,
                'rolling_oreb_pct_5G': rolling_oreb_pct_5G,
                'rolling_dreb_pct_5G': rolling_dreb_pct_5G,
                'rolling_reb_pct_5G': rolling_reb_pct_5G,
                'rolling_poss_5g': rolling_poss_5G,
                'ast_to_poss_ratio': ast_to_poss_ratio,
                'usg_to_poss_ratio': usg_to_poss_ratio,
                'engagement_index': engagement_index,
                'volume_efficiency_ratio': volume_efficiency_ratio,
                'starts_as_C': int(start_pos == 'C') if is_valid_start else 0,
                'starts_as_G': int(start_pos == 'G') if is_valid_start else 0,
                'starts_as_F': int(start_pos == 'F') if is_valid_start else 0,
                'is_starter': int(is_valid_start),
                'rolling_pts_from_2_5g': rolling_pts_from_2_5g,
                'rolling_pts_from_3_5g': rolling_pts_from_3_5g,
                'rolling_pts_from_ft_5g': rolling_pts_from_ft_5g,
                'rolling_looseball_rec_5g': rolling_looseball_rec_5g,
                'rolling_screen_ast_5g': rolling_screen_ast_5g,
                'touches_to_pts_ratio': touches_to_pts_ratio,
                'transition_pts_pct': transition_pts_pct,
                'volume_times_efficiency': volume_times_efficiency,
                'usg_min_product': usg_min_product, 
                'scoring_touch_ratio': scoring_touch_ratio, 
                'volume_efficiency_to_pts': volume_efficiency_to_pts, 
                'adjusted_shot_creation': adjusted_shot_creation, 
                'PTS': current_game['PTS']
                }

            feature_rows.append(row)

        return pd.DataFrame(feature_rows)

# %%
from ___team_data import players_by_team  # Your custom module

fb = FeatureBuilder(players_by_team, season='2024-25', rolling_window=5)
features_df = fb.generate_features()

# Optional: Quickly inspect NaN situation
#print(features_df.isna().mean().sort_values(ascending=False).head(20))

# Make sure all binary columns are integers (0 or 1)
binary_cols = [
    'HOME_AWAY', 'is_b2b', 'is_volume_shooter', 'is_trending_up',
    'is_trending_down', 'high_efficiency', 'starts_as_C',
    'starts_as_G', 'starts_as_F', 'is_starter'
]

# 1. Fill missing binary values with 0
features_df[binary_cols] = features_df[binary_cols].fillna(0)

# Convert to 0/1 integers if needed
features_df[binary_cols] = features_df[binary_cols].astype(int)

# 3. (Optional) Check if any NaNs remain anywhere
nan_report = features_df.isna().sum().sort_values(ascending=False)
print(nan_report[nan_report > 0])  # Shows only columns still having NaN (if any)

#display(features_df.head(100))
features_df.to_csv("nba_player_features_rolling5G.csv", index=False)
# Out:
# [+] Processing team: Celtics
#     - Fetching: Jayson Tatum
# [!] No advanced stats found for PLAYER_ID 1628369 on 2025-04-11
#     - Fetching: Jaylen Brown
#     - Fetching: Derrick White
# [!] No advanced stats found for PLAYER_ID 1628401 on 2025-04-11
#     - Fetching: Jrue Holiday
# [!] No advanced stats found for PLAYER_ID 201950 on 2025-04-11
#     - Fetching: Payton Pritchard
# [!] No advanced stats found for PLAYER_ID 1630202 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630202 on 2025-04-13
#     - Fetching: Kristaps Porzingis
# [!] Player ID not found for Kristaps Porzingis
#       Skipping Kristaps Porzingis, not enough data.
#
# [+] Processing team: Knicks
#     - Fetching: Karl-Anthony Towns
# [!] No advanced stats found for PLAYER_ID 1626157 on 2025-04-10
#     - Fetching: Jalen Brunson
# [!] No advanced stats found for PLAYER_ID 1628973 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1628973 on 2025-04-11
#     - Fetching: OG Anunoby
# [!] No advanced stats found for PLAYER_ID 1628384 on 2025-04-11
#     - Fetching: Mikal Bridges
# [!] No advanced stats found for PLAYER_ID 1628969 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1628969 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1628969 on 2025-04-13
#     - Fetching: Josh Hart
# [!] No advanced stats found for PLAYER_ID 1628404 on 2025-04-11
#     - Fetching: Miles McBride
# [!] No advanced stats found for PLAYER_ID 1630540 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630540 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630540 on 2025-04-13
#
# [+] Processing team: Cavs
#     - Fetching: Donovan Mitchell
# [!] No advanced stats found for PLAYER_ID 1628378 on 2024-11-29
#     - Fetching: Darius Garland
# [!] No advanced stats found for PLAYER_ID 1629636 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1629636 on 2025-04-11
#     - Fetching: Evan Mobley
# [!] No advanced stats found for PLAYER_ID 1630596 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1630596 on 2025-04-11
#     - Fetching: Jarrett Allen
# [!] No advanced stats found for PLAYER_ID 1628386 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1628386 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1628386 on 2025-04-13
#     - Fetching: Dean Wade
# [!] No advanced stats found for PLAYER_ID 1629731 on 2025-04-11
#     - Fetching: Max Strus
# [!] No advanced stats found for PLAYER_ID 1629622 on 2025-04-11
#     - Fetching: De'Andre Hunter
# [!] No advanced stats found for PLAYER_ID 1629631 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1629631 on 2025-01-28
#     - Fetching: Ty Jerome
# [!] No advanced stats found for PLAYER_ID 1629660 on 2024-11-29
#
# [+] Processing team: Pistons
#     - Fetching: Cade Cunningham
# [!] No advanced stats found for PLAYER_ID 1630595 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630595 on 2025-04-11
#     - Fetching: Tim Hardaway Jr
# [!] Player ID not found for Tim Hardaway Jr
#       Skipping Tim Hardaway Jr, not enough data.
#     - Fetching: Ausar Thompson
# [!] No advanced stats found for PLAYER_ID 1641709 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1641709 on 2025-04-11
#     - Fetching: Tobias Harris
# [!] No advanced stats found for PLAYER_ID 202699 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 202699 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 202699 on 2025-04-13
#     - Fetching: Malik Beasley
# [!] No advanced stats found for PLAYER_ID 1627736 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1627736 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627736 on 2025-04-13
#     - Fetching: Jalen Duren
# [!] No advanced stats found for PLAYER_ID 1631105 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1631105 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1631105 on 2025-04-13
#     - Fetching: Dennis Schroder
# [!] Player ID not found for Dennis Schroder
#       Skipping Dennis Schroder, not enough data.
#     - Fetching: Isaiah Stewart
# [!] No advanced stats found for PLAYER_ID 1630191 on 2025-04-10
#
# [+] Processing team: Magic
#     - Fetching: Cole Anthony
# [!] No advanced stats found for PLAYER_ID 1630175 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630175 on 2025-04-13
#     - Fetching: Kentavious Caldwell-Pope
# [!] No advanced stats found for PLAYER_ID 203484 on 2025-04-13
#     - Fetching: Franz Wagner
#     - Fetching: Paolo Banchero
#     - Fetching: Goga Bitadze
# [!] No advanced stats found for PLAYER_ID 1629048 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1629048 on 2025-04-13
#     - Fetching: Wendell Carter Jr
# [!] Player ID not found for Wendell Carter Jr
#       Skipping Wendell Carter Jr, not enough data.
#
# [+] Processing team: Heat
#     - Fetching: Tyler Herro
# [!] No advanced stats found for PLAYER_ID 1629639 on 2025-04-11
#     - Fetching: Duncan Robinson
# [!] No advanced stats found for PLAYER_ID 1629130 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1629130 on 2025-04-13
#     - Fetching: Andrew Wiggins
# [!] No advanced stats found for PLAYER_ID 203952 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 203952 on 2025-04-11
#     - Fetching: Bam Adebayo
# [!] No advanced stats found for PLAYER_ID 1628389 on 2025-04-11
#     - Fetching: Kel'el Ware
# [!] No advanced stats found for PLAYER_ID 1642276 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1642276 on 2025-04-13
#     - Fetching: Terry Rozier
# [!] No advanced stats found for PLAYER_ID 1626179 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1626179 on 2025-04-13
#     - Fetching: Jaime Jaquez Jr
# [!] Player ID not found for Jaime Jaquez Jr
#       Skipping Jaime Jaquez Jr, not enough data.
#     - Fetching: Davion Mitchell
# [!] No advanced stats found for PLAYER_ID 1630558 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630558 on 2025-04-13
#
# [+] Processing team: Thunder
#     - Fetching: Shai Gilgeous-Alexander
# [!] No advanced stats found for PLAYER_ID 1628983 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1628983 on 2025-02-24
#     - Fetching: Jalen Williams
# [!] No advanced stats found for PLAYER_ID 1631114 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1631114 on 2025-02-24
#     - Fetching: Isaiah Joe
# [!] No advanced stats found for PLAYER_ID 1630198 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1630198 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1630198 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630198 on 2025-04-13
#     - Fetching: Luguentz Dort
# [!] No advanced stats found for PLAYER_ID 1629652 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1629652 on 2025-02-24
#     - Fetching: Isaiah Hartenstein
# [!] No advanced stats found for PLAYER_ID 1628392 on 2025-02-24
#     - Fetching: Aaron Wiggins
# [!] No advanced stats found for PLAYER_ID 1630598 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1630598 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1630598 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630598 on 2025-04-13
#     - Fetching: Cason Wallace
# [!] No advanced stats found for PLAYER_ID 1641717 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1641717 on 2025-02-24
#     - Fetching: Chet Holmgren
#
# [+] Processing team: Nuggets
#     - Fetching: Nikola Jokić
# [!] No advanced stats found for PLAYER_ID 203999 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 203999 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 203999 on 2025-04-13
#     - Fetching: Jamal Murray
# [!] No advanced stats found for PLAYER_ID 1627750 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1627750 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627750 on 2025-04-13
#     - Fetching: Michael Porter Jr.
# [!] No advanced stats found for PLAYER_ID 1629008 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1629008 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1629008 on 2025-04-13
#     - Fetching: Christian Braun
# [!] No advanced stats found for PLAYER_ID 1631128 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1631128 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1631128 on 2025-04-13
#     - Fetching: Aaron Gordon
# [!] No advanced stats found for PLAYER_ID 203932 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 203932 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 203932 on 2025-04-13
#     - Fetching: Russell Westbrook
# [!] No advanced stats found for PLAYER_ID 201566 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 201566 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 201566 on 2025-04-13
#     - Fetching: Julian Strawther
# [!] No advanced stats found for PLAYER_ID 1631124 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1631124 on 2025-04-13
#
# [+] Processing team: Timberwolves
#     - Fetching: Anthony Edwards
# [!] No advanced stats found for PLAYER_ID 1630162 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1630162 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630162 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630162 on 2025-04-13
#     - Fetching: Julius Randle
# [!] No advanced stats found for PLAYER_ID 203944 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 203944 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 203944 on 2025-04-13
#     - Fetching: Jaden McDaniels
# [!] No advanced stats found for PLAYER_ID 1630183 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1630183 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630183 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630183 on 2025-04-13
#     - Fetching: Rudy Gobert
# [!] No advanced stats found for PLAYER_ID 203497 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 203497 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 203497 on 2025-04-13
#     - Fetching: Mike Conley
# [!] No advanced stats found for PLAYER_ID 201144 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 201144 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 201144 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 201144 on 2025-04-13
#     - Fetching: Donte DiVincenzo
# [!] No advanced stats found for PLAYER_ID 1628978 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1628978 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1628978 on 2025-04-13
#     - Fetching: Naz Reid
# [!] No advanced stats found for PLAYER_ID 1629675 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1629675 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1629675 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1629675 on 2025-04-13
#     - Fetching: Nickeil Alexander-Walker
# [!] No advanced stats found for PLAYER_ID 1629638 on 2025-02-24
# [!] No advanced stats found for PLAYER_ID 1629638 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1629638 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1629638 on 2025-04-13
#
# [+] Processing team: Warriors
#     - Fetching: Stephen Curry
# [!] No advanced stats found for PLAYER_ID 201939 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 201939 on 2025-04-13
#     - Fetching: Buddy Hield
# [!] No advanced stats found for PLAYER_ID 1627741 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1627741 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627741 on 2025-04-13
#     - Fetching: Draymond Green
# [!] No advanced stats found for PLAYER_ID 203110 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 203110 on 2025-04-13
#     - Fetching: Jimmy Butler
# [!] No advanced stats found for PLAYER_ID 202710 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 202710 on 2025-04-13
#     - Fetching: Jonathan Kuminga
# [!] No advanced stats found for PLAYER_ID 1630228 on 2025-04-11
#     - Fetching: Brandin Podziemski
# [!] No advanced stats found for PLAYER_ID 1641764 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1641764 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1641764 on 2025-04-13
#     - Fetching: Quinten Post
# [!] No advanced stats found for PLAYER_ID 1642366 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1642366 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1642366 on 2025-04-13
#
# [+] Processing team: Clippers
#     - Fetching: James Harden
# [!] No advanced stats found for PLAYER_ID 201935 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 201935 on 2025-04-13
#     - Fetching: Ivica Zubac
# [!] No advanced stats found for PLAYER_ID 1627826 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627826 on 2025-04-13
#     - Fetching: Norman Powell
# [!] No advanced stats found for PLAYER_ID 1626181 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1626181 on 2025-04-13
#     - Fetching: Derrick Jones Jr.
# [!] No advanced stats found for PLAYER_ID 1627884 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627884 on 2025-04-13
#     - Fetching: Kris Dunn
# [!] No advanced stats found for PLAYER_ID 1627739 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1627739 on 2025-04-13
#     - Fetching: Amir Coffey
# [!] No advanced stats found for PLAYER_ID 1629599 on 2025-04-13
#     - Fetching: Bogdan Bogdanovic
# [!] Player ID not found for Bogdan Bogdanovic
#       Skipping Bogdan Bogdanovic, not enough data.
#
# [+] Processing team: Lakers
#     - Fetching: Luka Dončić
# [!] No advanced stats found for PLAYER_ID 1629029 on 2025-04-11
#     - Fetching: LeBron James
# [!] No advanced stats found for PLAYER_ID 2544 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 2544 on 2025-04-11
#     - Fetching: Austin Reaves
# [!] No advanced stats found for PLAYER_ID 1630559 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1630559 on 2025-04-11
#     - Fetching: Rui Hachimura
# [!] No advanced stats found for PLAYER_ID 1629060 on 2024-11-29
# [!] No advanced stats found for PLAYER_ID 1629060 on 2024-12-08
# [!] No advanced stats found for PLAYER_ID 1629060 on 2025-04-11
#     - Fetching: Jaxson Hayes
# [!] No advanced stats found for PLAYER_ID 1629637 on 2025-04-11
#     - Fetching: Dorian Finney-Smith
# [!] No advanced stats found for PLAYER_ID 1627827 on 2024-12-08
# [!] No advanced stats found for PLAYER_ID 1627827 on 2025-04-11
#
# [+] Processing team: Rockets
#     - Fetching: Jalen Green
# [!] No advanced stats found for PLAYER_ID 1630224 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1630224 on 2025-04-11
# [!] No advanced stats found for PLAYER_ID 1630224 on 2025-04-13
#     - Fetching: Alperen Sengun
# [!] No advanced stats found for PLAYER_ID 1630578 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1630578 on 2025-04-13
#     - Fetching: Fred VanVleet
# [!] No advanced stats found for PLAYER_ID 1627832 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1627832 on 2025-04-13
#     - Fetching: Dillon Brooks
# [!] No advanced stats found for PLAYER_ID 1628415 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1628415 on 2025-04-13
#     - Fetching: Jabari Smith Jr
# [!] Player ID not found for Jabari Smith Jr
#       Skipping Jabari Smith Jr, not enough data.
#     - Fetching: Amen Thompson
# [!] No advanced stats found for PLAYER_ID 1641708 on 2025-01-28
# [!] No advanced stats found for PLAYER_ID 1641708 on 2025-04-13
#
# [+] Processing team: Grizzlies
#     - Fetching: Jaren Jackson Jr
# [!] Player ID not found for Jaren Jackson Jr
#       Skipping Jaren Jackson Jr, not enough data.
#     - Fetching: Ja Morant
# [!] No advanced stats found for PLAYER_ID 1629630 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1629630 on 2025-04-11
#     - Fetching: Santi Aldama
# [!] No advanced stats found for PLAYER_ID 1630583 on 2024-12-08
# [!] No advanced stats found for PLAYER_ID 1630583 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630583 on 2025-04-11
#     - Fetching: Desmond Bane
# [!] No advanced stats found for PLAYER_ID 1630217 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630217 on 2025-04-11
#     - Fetching: Zach Edey
# [!] No advanced stats found for PLAYER_ID 1641744 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1641744 on 2025-04-11
#     - Fetching: Jaylen Wells
# [!] No advanced stats found for PLAYER_ID 1642377 on 2024-12-08
#     - Fetching: Scotty Pippen Jr.
# [!] No advanced stats found for PLAYER_ID 1630590 on 2024-12-08
# [!] No advanced stats found for PLAYER_ID 1630590 on 2025-04-10
# [!] No advanced stats found for PLAYER_ID 1630590 on 2025-04-11
#     - Fetching: Luke Kennard
# [!] No advanced stats found for PLAYER_ID 1628379 on 2025-04-11
# delta_min_vs_rolling    1
# dtype: int64

# %%
from scipy.stats import pointbiserialr
from sklearn.feature_selection import mutual_info_classif

def add_threshold_targets(df):
    df['hit_10pts'] = (df['rolling_pts_avg_5G'] >= 10).astype(int)
    df['hit_15pts'] = (df['rolling_pts_avg_5G'] >= 15).astype(int)
    df['hit_20pts'] = (df['rolling_pts_avg_5G'] >= 20).astype(int)
    df['hit_25pts'] = (df['rolling_pts_avg_5G'] >= 25).astype(int)
    return df

def compute_pointbiserial_correlations(df, target_col, feature_cols):
    print(f"\n--- Correlation with: {target_col} ---")
    for feature in feature_cols:
        try:
            corr, p = pointbiserialr(df[target_col], df[feature])
            print(f"{feature:<30} -> Corr: {corr:.4f} (p={p:.4f})")
        except Exception as e:
            print(f"{feature:<30} -> ERROR: {e}")

def compute_mutual_info(df, target_col, feature_cols):
    print(f"\n--- Mutual Info with: {target_col} ---")
    X = df[feature_cols].fillna(0)
    y = df[target_col]
    mi = mutual_info_classif(X, y, discrete_features=False, random_state=42)
    for feat, score in zip(feature_cols, mi):
        print(f"{feat:<30} -> MI Score: {score:.4f}")

# %%
features_df = add_threshold_targets(features_df)

important_features = [
    'rolling_pts_avg_5G', 'rolling_pts_median_5G', 'rolling_3pm_avg_5G', 'rolling_3pm_median_5G', 'rolling_min_avg_5G', 'rolling_std_pts_5G',  
    'pts_consistency_score', 'rolling_opp_def_rating_5G', 'rolling_opp_ast_pct_5G', 'rolling_team_off_rating_5G', 
    'rolling_team_reb_pct_5G', 'rolling_team_ast_pct_5G', 'rolling_opp_reb_pct_5G', 'latest_team_e_off_rating',
    'latest_opp_e_def_rating', 'adjusted_pts_proj_def', 'rolling_usg_pct_5G', 'rolling_fg_pct_5G',     
    'rolling_fg3_pct_5G', 'rolling_fga_5G', 'delta_pts_vs_rolling', 'delta_min_vs_rolling',          
    'opp_def_trend_delta', 'adjusted_pts_proj_usg', 'rest_days', 'is_b2b', 'team_pace', 'opp_pace',
    'shots_per_min', 'pts_per_fga', 'pts_per_min', 'pts_to_3pm_ratio', 'pts_trend_slope_5G', 'is_volume_shooter', 
    'is_trending_up', 'is_trending_down', 'high_efficiency', 'rolling_ast_pct_5G', 'rolling_oreb_pct_5G', 'rolling_dreb_pct_5G',
    'rolling_reb_pct_5G', 'ast_to_poss_ratio', 'usg_to_poss_ratio', 'engagement_index', 'volume_efficiency_ratio', 'starts_as_C',
    'starts_as_G', 'starts_as_F', 'is_starter', 'HOME_AWAY', 'fg_pct_vs_avg_delta', 'delta_fga_vs_rolling',
    'rolling_pts_from_2_5g', 'rolling_pts_from_3_5g', 'rolling_pts_from_ft_5g', 'rolling_looseball_rec_5g', 'rolling_screen_ast_5g', 
    'touches_to_pts_ratio', 'transition_pts_pct','rolling_opp_blocks_5g', 'rolling_opp_steals_5g', 'rolling_opp_fouls_5g',
    'volume_times_efficiency', 'usg_min_product', 'scoring_touch_ratio', 'volume_efficiency_to_pts', 'adjusted_shot_creation', 'rolling_e_usg_pct_5G'
]

features_df[['PLAYER_NAME', 'GAME_DATE', 'rolling_pts_avg_5G', 'hit_15pts']].head()

compute_pointbiserial_correlations(features_df, 'hit_10pts', important_features)
compute_pointbiserial_correlations(features_df, 'hit_15pts', important_features)
compute_pointbiserial_correlations(features_df, 'hit_20pts', important_features)
compute_pointbiserial_correlations(features_df, 'hit_25pts', important_features)
compute_mutual_info(features_df, 'hit_10pts', important_features)
compute_mutual_info(features_df, 'hit_15pts', important_features)
compute_mutual_info(features_df, 'hit_20pts', important_features)
compute_mutual_info(features_df, 'hit_25pts', important_features)
# Out:
# --- Correlation with: hit_10pts ---
# rolling_pts_avg_5G             -> Corr: 0.6488 (p=0.0000)
# rolling_pts_median_5G          -> Corr: 0.6315 (p=0.0000)
# rolling_3pm_avg_5G             -> Corr: 0.3581 (p=0.0000)
# rolling_3pm_median_5G          -> Corr: 0.3332 (p=0.0000)
# rolling_min_avg_5G             -> Corr: 0.5936 (p=0.0000)
# rolling_std_pts_5G             -> Corr: 0.3502 (p=0.0000)
# pts_consistency_score          -> Corr: 0.0075 (p=0.5678)
# rolling_opp_def_rating_5G      -> Corr: 0.0140 (p=0.2853)
# rolling_opp_ast_pct_5G         -> Corr: 0.0072 (p=0.5827)
# rolling_team_off_rating_5G     -> Corr: 0.0547 (p=0.0000)
# rolling_team_reb_pct_5G        -> Corr: 0.0441 (p=0.0008)
# rolling_team_ast_pct_5G        -> Corr: 0.0082 (p=0.5344)
# rolling_opp_reb_pct_5G         -> Corr: 0.0117 (p=0.3726)
# latest_team_e_off_rating       -> Corr: 0.0513 (p=0.0001)
# latest_opp_e_def_rating        -> Corr: 0.0162 (p=0.2184)
# adjusted_pts_proj_def          -> Corr: 0.6488 (p=0.0000)
# rolling_usg_pct_5G             -> Corr: 0.5212 (p=0.0000)
# rolling_fg_pct_5G              -> Corr: 0.2331 (p=0.0000)
# rolling_fg3_pct_5G             -> Corr: 0.1921 (p=0.0000)
# rolling_fga_5G                 -> Corr: 0.6134 (p=0.0000)
# delta_pts_vs_rolling           -> Corr: 0.0004 (p=0.9745)
# delta_min_vs_rolling           -> Corr: nan (p=nan)
# opp_def_trend_delta            -> Corr: 0.0114 (p=0.3868)
# adjusted_pts_proj_usg          -> Corr: 0.6488 (p=0.0000)
# rest_days                      -> Corr: -0.0086 (p=0.5112)
# is_b2b                         -> Corr: -0.0000 (p=1.0000)
# team_pace                      -> Corr: -0.0402 (p=0.0022)
# opp_pace                       -> Corr: 0.0206 (p=0.1167)
# shots_per_min                  -> Corr: 0.5185 (p=0.0000)
# pts_per_fga                    -> Corr: 0.2939 (p=0.0000)
# pts_per_min                    -> Corr: 0.5970 (p=0.0000)
# pts_to_3pm_ratio               -> Corr: 0.0097 (p=0.4600)
# pts_trend_slope_5G             -> Corr: 0.0027 (p=0.8384)
# is_volume_shooter              -> Corr: 0.3450 (p=0.0000)
# is_trending_up                 -> Corr: 0.0021 (p=0.8722)
# is_trending_down               -> Corr: 0.0203 (p=0.1214)
# high_efficiency                -> Corr: 0.2976 (p=0.0000)
# rolling_ast_pct_5G             -> Corr: 0.2340 (p=0.0000)
# rolling_oreb_pct_5G            -> Corr: -0.0087 (p=0.5097)
# rolling_dreb_pct_5G            -> Corr: 0.1235 (p=0.0000)
# rolling_reb_pct_5G             -> Corr: 0.0865 (p=0.0000)
# ast_to_poss_ratio              -> Corr: -0.0496 (p=0.0002)
# usg_to_poss_ratio              -> Corr: 0.0327 (p=0.0129)
# engagement_index               -> Corr: 0.3926 (p=0.0000)
# volume_efficiency_ratio        -> Corr: 0.5698 (p=0.0000)
# starts_as_C                    -> Corr: 0.0143 (p=0.2761)
# starts_as_G                    -> Corr: 0.1387 (p=0.0000)
# starts_as_F                    -> Corr: 0.1256 (p=0.0000)
# is_starter                     -> Corr: 0.2802 (p=0.0000)
# HOME_AWAY                      -> Corr: -0.0118 (p=0.3693)
# fg_pct_vs_avg_delta            -> Corr: -0.1577 (p=0.0000)
# delta_fga_vs_rolling           -> Corr: -0.1390 (p=0.0000)
# rolling_pts_from_2_5g          -> Corr: 0.5289 (p=0.0000)
# rolling_pts_from_3_5g          -> Corr: 0.3573 (p=0.0000)
# rolling_pts_from_ft_5g         -> Corr: 0.4579 (p=0.0000)
# rolling_looseball_rec_5g       -> Corr: 0.1717 (p=0.0000)
# rolling_screen_ast_5g          -> Corr: 0.0046 (p=0.7290)
# touches_to_pts_ratio           -> Corr: 0.4428 (p=0.0000)
# transition_pts_pct             -> Corr: -0.0432 (p=0.0010)
# rolling_opp_blocks_5g          -> Corr: -0.0238 (p=0.0697)
# rolling_opp_steals_5g          -> Corr: -0.0151 (p=0.2517)
# rolling_opp_fouls_5g           -> Corr: 0.0133 (p=0.3129)
# volume_times_efficiency        -> Corr: 0.6488 (p=0.0000)
# usg_min_product                -> Corr: 0.6008 (p=0.0000)
# scoring_touch_ratio            -> Corr: 0.5167 (p=0.0000)
# volume_efficiency_to_pts       -> Corr: 0.5180 (p=0.0000)
# adjusted_shot_creation         -> Corr: 0.6117 (p=0.0000)
# rolling_e_usg_pct_5G           -> Corr: 0.5155 (p=0.0000)
#
# --- Correlation with: hit_15pts ---
# rolling_pts_avg_5G             -> Corr: 0.8217 (p=0.0000)
# rolling_pts_median_5G          -> Corr: 0.8005 (p=0.0000)
# rolling_3pm_avg_5G             -> Corr: 0.4365 (p=0.0000)
# rolling_3pm_median_5G          -> Corr: 0.4096 (p=0.0000)
# rolling_min_avg_5G             -> Corr: 0.6200 (p=0.0000)
# rolling_std_pts_5G             -> Corr: 0.3669 (p=0.0000)
# pts_consistency_score          -> Corr: -0.0121 (p=0.3569)
# rolling_opp_def_rating_5G      -> Corr: 0.0066 (p=0.6174)
# rolling_opp_ast_pct_5G         -> Corr: 0.0049 (p=0.7076)
# rolling_team_off_rating_5G     -> Corr: 0.0471 (p=0.0003)
# rolling_team_reb_pct_5G        -> Corr: 0.0068 (p=0.6062)
# rolling_team_ast_pct_5G        -> Corr: -0.0120 (p=0.3612)
# rolling_opp_reb_pct_5G         -> Corr: -0.0019 (p=0.8846)
# latest_team_e_off_rating       -> Corr: 0.0488 (p=0.0002)
# latest_opp_e_def_rating        -> Corr: 0.0095 (p=0.4684)
# adjusted_pts_proj_def          -> Corr: 0.8217 (p=0.0000)
# rolling_usg_pct_5G             -> Corr: 0.7163 (p=0.0000)
# rolling_fg_pct_5G              -> Corr: 0.1143 (p=0.0000)
# rolling_fg3_pct_5G             -> Corr: 0.2124 (p=0.0000)
# rolling_fga_5G                 -> Corr: 0.7951 (p=0.0000)
# delta_pts_vs_rolling           -> Corr: -0.0105 (p=0.4219)
# delta_min_vs_rolling           -> Corr: nan (p=nan)
# opp_def_trend_delta            -> Corr: 0.0155 (p=0.2394)
# adjusted_pts_proj_usg          -> Corr: 0.8217 (p=0.0000)
# rest_days                      -> Corr: 0.0035 (p=0.7894)
# is_b2b                         -> Corr: 0.0019 (p=0.8856)
# team_pace                      -> Corr: -0.0689 (p=0.0000)
# opp_pace                       -> Corr: 0.0037 (p=0.7755)
# shots_per_min                  -> Corr: 0.6904 (p=0.0000)
# pts_per_fga                    -> Corr: 0.2186 (p=0.0000)
# pts_per_min                    -> Corr: 0.7413 (p=0.0000)
# pts_to_3pm_ratio               -> Corr: -0.0816 (p=0.0000)
# pts_trend_slope_5G             -> Corr: 0.0017 (p=0.8943)
# is_volume_shooter              -> Corr: 0.6529 (p=0.0000)
# is_trending_up                 -> Corr: 0.0040 (p=0.7617)
# is_trending_down               -> Corr: 0.0120 (p=0.3607)
# high_efficiency                -> Corr: 0.2525 (p=0.0000)
# rolling_ast_pct_5G             -> Corr: 0.4081 (p=0.0000)
# rolling_oreb_pct_5G            -> Corr: -0.0962 (p=0.0000)
# rolling_dreb_pct_5G            -> Corr: 0.1097 (p=0.0000)
# rolling_reb_pct_5G             -> Corr: 0.0435 (p=0.0009)
# ast_to_poss_ratio              -> Corr: 0.1015 (p=0.0000)
# usg_to_poss_ratio              -> Corr: 0.1773 (p=0.0000)
# engagement_index               -> Corr: 0.5777 (p=0.0000)
# volume_efficiency_ratio        -> Corr: 0.7295 (p=0.0000)
# starts_as_C                    -> Corr: -0.0286 (p=0.0293)
# starts_as_G                    -> Corr: 0.2482 (p=0.0000)
# starts_as_F                    -> Corr: 0.0945 (p=0.0000)
# is_starter                     -> Corr: 0.3301 (p=0.0000)
# HOME_AWAY                      -> Corr: 0.0008 (p=0.9496)
# fg_pct_vs_avg_delta            -> Corr: -0.0915 (p=0.0000)
# delta_fga_vs_rolling           -> Corr: -0.0924 (p=0.0000)
# rolling_pts_from_2_5g          -> Corr: 0.6498 (p=0.0000)
# rolling_pts_from_3_5g          -> Corr: 0.4369 (p=0.0000)
# rolling_pts_from_ft_5g         -> Corr: 0.6556 (p=0.0000)
# rolling_looseball_rec_5g       -> Corr: 0.1800 (p=0.0000)
# rolling_screen_ast_5g          -> Corr: -0.0503 (p=0.0001)
# touches_to_pts_ratio           -> Corr: 0.4312 (p=0.0000)
# transition_pts_pct             -> Corr: -0.0812 (p=0.0000)
# rolling_opp_blocks_5g          -> Corr: -0.0092 (p=0.4818)
# rolling_opp_steals_5g          -> Corr: 0.0018 (p=0.8893)
# rolling_opp_fouls_5g           -> Corr: 0.0068 (p=0.6040)
# volume_times_efficiency        -> Corr: 0.8217 (p=0.0000)
# usg_min_product                -> Corr: 0.7954 (p=0.0000)
# scoring_touch_ratio            -> Corr: 0.6425 (p=0.0000)
# volume_efficiency_to_pts       -> Corr: 0.7462 (p=0.0000)
# adjusted_shot_creation         -> Corr: 0.7949 (p=0.0000)
# rolling_e_usg_pct_5G           -> Corr: 0.7118 (p=0.0000)
#
# --- Correlation with: hit_20pts ---
# rolling_pts_avg_5G             -> Corr: 0.8103 (p=0.0000)
# rolling_pts_median_5G          -> Corr: 0.7792 (p=0.0000)
# rolling_3pm_avg_5G             -> Corr: 0.4451 (p=0.0000)
# rolling_3pm_median_5G          -> Corr: 0.4229 (p=0.0000)
# rolling_min_avg_5G             -> Corr: 0.5074 (p=0.0000)
# rolling_std_pts_5G             -> Corr: 0.3176 (p=0.0000)
# pts_consistency_score          -> Corr: -0.0077 (p=0.5586)
# rolling_opp_def_rating_5G      -> Corr: 0.0054 (p=0.6821)
# rolling_opp_ast_pct_5G         -> Corr: 0.0060 (p=0.6482)
# rolling_team_off_rating_5G     -> Corr: 0.0364 (p=0.0056)
# rolling_team_reb_pct_5G        -> Corr: -0.0033 (p=0.8040)
# rolling_team_ast_pct_5G        -> Corr: -0.0197 (p=0.1329)
# rolling_opp_reb_pct_5G         -> Corr: 0.0187 (p=0.1541)
# latest_team_e_off_rating       -> Corr: 0.0392 (p=0.0029)
# latest_opp_e_def_rating        -> Corr: 0.0074 (p=0.5715)
# adjusted_pts_proj_def          -> Corr: 0.8103 (p=0.0000)
# rolling_usg_pct_5G             -> Corr: 0.7264 (p=0.0000)
# rolling_fg_pct_5G              -> Corr: 0.0725 (p=0.0000)
# rolling_fg3_pct_5G             -> Corr: 0.2165 (p=0.0000)
# rolling_fga_5G                 -> Corr: 0.7713 (p=0.0000)
# delta_pts_vs_rolling           -> Corr: -0.0030 (p=0.8207)
# delta_min_vs_rolling           -> Corr: nan (p=nan)
# opp_def_trend_delta            -> Corr: 0.0107 (p=0.4138)
# adjusted_pts_proj_usg          -> Corr: 0.8103 (p=0.0000)
# rest_days                      -> Corr: 0.0190 (p=0.1490)
# is_b2b                         -> Corr: 0.0048 (p=0.7133)
# team_pace                      -> Corr: -0.0687 (p=0.0000)
# opp_pace                       -> Corr: 0.0136 (p=0.3006)
# shots_per_min                  -> Corr: 0.6890 (p=0.0000)
# pts_per_fga                    -> Corr: 0.1873 (p=0.0000)
# pts_per_min                    -> Corr: 0.7413 (p=0.0000)
# pts_to_3pm_ratio               -> Corr: -0.1367 (p=0.0000)
# pts_trend_slope_5G             -> Corr: -0.0012 (p=0.9295)
# is_volume_shooter              -> Corr: 0.8141 (p=0.0000)
# is_trending_up                 -> Corr: 0.0091 (p=0.4890)
# is_trending_down               -> Corr: 0.0070 (p=0.5966)
# high_efficiency                -> Corr: 0.2381 (p=0.0000)
# rolling_ast_pct_5G             -> Corr: 0.4826 (p=0.0000)
# rolling_oreb_pct_5G            -> Corr: -0.1752 (p=0.0000)
# rolling_dreb_pct_5G            -> Corr: 0.0937 (p=0.0000)
# rolling_reb_pct_5G             -> Corr: 0.0017 (p=0.8987)
# ast_to_poss_ratio              -> Corr: 0.1961 (p=0.0000)
# usg_to_poss_ratio              -> Corr: 0.2419 (p=0.0000)
# engagement_index               -> Corr: 0.6184 (p=0.0000)
# volume_efficiency_ratio        -> Corr: 0.7434 (p=0.0000)
# starts_as_C                    -> Corr: -0.0406 (p=0.0020)
# starts_as_G                    -> Corr: 0.3004 (p=0.0000)
# starts_as_F                    -> Corr: 0.0123 (p=0.3504)
# is_starter                     -> Corr: 0.2934 (p=0.0000)
# HOME_AWAY                      -> Corr: 0.0075 (p=0.5664)
# fg_pct_vs_avg_delta            -> Corr: -0.0688 (p=0.0000)
# delta_fga_vs_rolling           -> Corr: -0.0738 (p=0.0000)
# rolling_pts_from_2_5g          -> Corr: 0.6164 (p=0.0000)
# rolling_pts_from_3_5g          -> Corr: 0.4450 (p=0.0000)
# rolling_pts_from_ft_5g         -> Corr: 0.6832 (p=0.0000)
# rolling_looseball_rec_5g       -> Corr: 0.1343 (p=0.0000)
# rolling_screen_ast_5g          -> Corr: -0.0946 (p=0.0000)
# touches_to_pts_ratio           -> Corr: 0.3636 (p=0.0000)
# transition_pts_pct             -> Corr: -0.0782 (p=0.0000)
# rolling_opp_blocks_5g          -> Corr: 0.0000 (p=0.9999)
# rolling_opp_steals_5g          -> Corr: 0.0016 (p=0.9009)
# rolling_opp_fouls_5g           -> Corr: -0.0035 (p=0.7921)
# volume_times_efficiency        -> Corr: 0.8103 (p=0.0000)
# usg_min_product                -> Corr: 0.7835 (p=0.0000)
# scoring_touch_ratio            -> Corr: 0.6424 (p=0.0000)
# volume_efficiency_to_pts       -> Corr: 0.8211 (p=0.0000)
# adjusted_shot_creation         -> Corr: 0.7729 (p=0.0000)
# rolling_e_usg_pct_5G           -> Corr: 0.7220 (p=0.0000)
#
# --- Correlation with: hit_25pts ---
# rolling_pts_avg_5G             -> Corr: 0.6831 (p=0.0000)
# rolling_pts_median_5G          -> Corr: 0.6500 (p=0.0000)
# rolling_3pm_avg_5G             -> Corr: 0.3563 (p=0.0000)
# rolling_3pm_median_5G          -> Corr: 0.3464 (p=0.0000)
# rolling_min_avg_5G             -> Corr: 0.3614 (p=0.0000)
# rolling_std_pts_5G             -> Corr: 0.2662 (p=0.0000)
# pts_consistency_score          -> Corr: -0.0047 (p=0.7188)
# rolling_opp_def_rating_5G      -> Corr: 0.0224 (p=0.0880)
# rolling_opp_ast_pct_5G         -> Corr: -0.0021 (p=0.8737)
# rolling_team_off_rating_5G     -> Corr: 0.0439 (p=0.0008)
# rolling_team_reb_pct_5G        -> Corr: -0.0019 (p=0.8830)
# rolling_team_ast_pct_5G        -> Corr: -0.0240 (p=0.0678)
# rolling_opp_reb_pct_5G         -> Corr: 0.0203 (p=0.1225)
# latest_team_e_off_rating       -> Corr: 0.0498 (p=0.0001)
# latest_opp_e_def_rating        -> Corr: 0.0265 (p=0.0436)
# adjusted_pts_proj_def          -> Corr: 0.6831 (p=0.0000)
# rolling_usg_pct_5G             -> Corr: 0.5907 (p=0.0000)
# rolling_fg_pct_5G              -> Corr: 0.0683 (p=0.0000)
# rolling_fg3_pct_5G             -> Corr: 0.1645 (p=0.0000)
# rolling_fga_5G                 -> Corr: 0.6214 (p=0.0000)
# delta_pts_vs_rolling           -> Corr: 0.0030 (p=0.8213)
# delta_min_vs_rolling           -> Corr: nan (p=nan)
# opp_def_trend_delta            -> Corr: 0.0217 (p=0.0978)
# adjusted_pts_proj_usg          -> Corr: 0.6831 (p=0.0000)
# rest_days                      -> Corr: 0.0275 (p=0.0364)
# is_b2b                         -> Corr: 0.0069 (p=0.5993)
# team_pace                      -> Corr: -0.1072 (p=0.0000)
# opp_pace                       -> Corr: 0.0143 (p=0.2772)
# shots_per_min                  -> Corr: 0.5617 (p=0.0000)
# pts_per_fga                    -> Corr: 0.1768 (p=0.0000)
# pts_per_min                    -> Corr: 0.6337 (p=0.0000)
# pts_to_3pm_ratio               -> Corr: -0.1097 (p=0.0000)
# pts_trend_slope_5G             -> Corr: 0.0038 (p=0.7709)
# is_volume_shooter              -> Corr: 0.5954 (p=0.0000)
# is_trending_up                 -> Corr: 0.0112 (p=0.3938)
# is_trending_down               -> Corr: 0.0023 (p=0.8619)
# high_efficiency                -> Corr: 0.2186 (p=0.0000)
# rolling_ast_pct_5G             -> Corr: 0.3983 (p=0.0000)
# rolling_oreb_pct_5G            -> Corr: -0.1232 (p=0.0000)
# rolling_dreb_pct_5G            -> Corr: 0.1098 (p=0.0000)
# rolling_reb_pct_5G             -> Corr: 0.0342 (p=0.0092)
# ast_to_poss_ratio              -> Corr: 0.1762 (p=0.0000)
# usg_to_poss_ratio              -> Corr: 0.2181 (p=0.0000)
# engagement_index               -> Corr: 0.5164 (p=0.0000)
# volume_efficiency_ratio        -> Corr: 0.6338 (p=0.0000)
# starts_as_C                    -> Corr: -0.0116 (p=0.3781)
# starts_as_G                    -> Corr: 0.2107 (p=0.0000)
# starts_as_F                    -> Corr: -0.0142 (p=0.2806)
# is_starter                     -> Corr: 0.1962 (p=0.0000)
# HOME_AWAY                      -> Corr: 0.0298 (p=0.0234)
# fg_pct_vs_avg_delta            -> Corr: -0.0464 (p=0.0004)
# delta_fga_vs_rolling           -> Corr: -0.0602 (p=0.0000)
# rolling_pts_from_2_5g          -> Corr: 0.5153 (p=0.0000)
# rolling_pts_from_3_5g          -> Corr: 0.3552 (p=0.0000)
# rolling_pts_from_ft_5g         -> Corr: 0.6176 (p=0.0000)
# rolling_looseball_rec_5g       -> Corr: 0.0723 (p=0.0000)
# rolling_screen_ast_5g          -> Corr: -0.0522 (p=0.0001)
# touches_to_pts_ratio           -> Corr: 0.2876 (p=0.0000)
# transition_pts_pct             -> Corr: -0.0586 (p=0.0000)
# rolling_opp_blocks_5g          -> Corr: -0.0270 (p=0.0398)
# rolling_opp_steals_5g          -> Corr: -0.0314 (p=0.0166)
# rolling_opp_fouls_5g           -> Corr: -0.0037 (p=0.7784)
# volume_times_efficiency        -> Corr: 0.6831 (p=0.0000)
# usg_min_product                -> Corr: 0.6320 (p=0.0000)
# scoring_touch_ratio            -> Corr: 0.5651 (p=0.0000)
# volume_efficiency_to_pts       -> Corr: 0.7610 (p=0.0000)
# adjusted_shot_creation         -> Corr: 0.6228 (p=0.0000)
# rolling_e_usg_pct_5G           -> Corr: 0.5878 (p=0.0000)
#
# --- Mutual Info with: hit_10pts ---
# rolling_pts_avg_5G             -> MI Score: 0.5561
# rolling_pts_median_5G          -> MI Score: 0.3810
# rolling_3pm_avg_5G             -> MI Score: 0.1054
# rolling_3pm_median_5G          -> MI Score: 0.0821
# rolling_min_avg_5G             -> MI Score: 0.1980
# rolling_std_pts_5G             -> MI Score: 0.0982
# pts_consistency_score          -> MI Score: 0.1691
# rolling_opp_def_rating_5G      -> MI Score: 0.0000
# rolling_opp_ast_pct_5G         -> MI Score: 0.0047
# rolling_team_off_rating_5G     -> MI Score: 0.0129
# rolling_team_reb_pct_5G        -> MI Score: 0.0016
# rolling_team_ast_pct_5G        -> MI Score: 0.0000
# rolling_opp_reb_pct_5G         -> MI Score: 0.0000
# latest_team_e_off_rating       -> MI Score: 0.0000
# latest_opp_e_def_rating        -> MI Score: 0.0000
# adjusted_pts_proj_def          -> MI Score: 0.5563
# rolling_usg_pct_5G             -> MI Score: 0.2053
# rolling_fg_pct_5G              -> MI Score: 0.1082
# rolling_fg3_pct_5G             -> MI Score: 0.0645
# rolling_fga_5G                 -> MI Score: 0.3304
# delta_pts_vs_rolling           -> MI Score: 0.0342
# delta_min_vs_rolling           -> MI Score: 0.0000
# opp_def_trend_delta            -> MI Score: 0.0000
# adjusted_pts_proj_usg          -> MI Score: 0.5561
# rest_days                      -> MI Score: 0.0072
# is_b2b                         -> MI Score: 0.0000
# team_pace                      -> MI Score: 0.0044
# opp_pace                       -> MI Score: 0.0000
# shots_per_min                  -> MI Score: 0.1897
# pts_per_fga                    -> MI Score: 0.2028
# pts_per_min                    -> MI Score: 0.3085
# pts_to_3pm_ratio               -> MI Score: 0.2411
# pts_trend_slope_5G             -> MI Score: 0.0291
# is_volume_shooter              -> MI Score: 0.0834
# is_trending_up                 -> MI Score: 0.0051
# is_trending_down               -> MI Score: 0.0021
# high_efficiency                -> MI Score: 0.0464
# rolling_ast_pct_5G             -> MI Score: 0.0459
# rolling_oreb_pct_5G            -> MI Score: 0.0255
# rolling_dreb_pct_5G            -> MI Score: 0.0035
# rolling_reb_pct_5G             -> MI Score: 0.0063
# ast_to_poss_ratio              -> MI Score: 0.0180
# usg_to_poss_ratio              -> MI Score: 0.0538
# engagement_index               -> MI Score: 0.0964
# volume_efficiency_ratio        -> MI Score: 0.2625
# starts_as_C                    -> MI Score: 0.0000
# starts_as_G                    -> MI Score: 0.0096
# starts_as_F                    -> MI Score: 0.0130
# is_starter                     -> MI Score: 0.0320
# HOME_AWAY                      -> MI Score: 0.0000
# fg_pct_vs_avg_delta            -> MI Score: 0.0609
# delta_fga_vs_rolling           -> MI Score: 0.1321
# rolling_pts_from_2_5g          -> MI Score: 0.2084
# rolling_pts_from_3_5g          -> MI Score: 0.1016
# rolling_pts_from_ft_5g         -> MI Score: 0.1863
# rolling_looseball_rec_5g       -> MI Score: 0.0112
# rolling_screen_ast_5g          -> MI Score: 0.0164
# touches_to_pts_ratio           -> MI Score: 0.1298
# transition_pts_pct             -> MI Score: 0.1760
# rolling_opp_blocks_5g          -> MI Score: 0.0022
# rolling_opp_steals_5g          -> MI Score: 0.0008
# rolling_opp_fouls_5g           -> MI Score: 0.0058
# volume_times_efficiency        -> MI Score: 0.5561
# usg_min_product                -> MI Score: 0.3399
# scoring_touch_ratio            -> MI Score: 0.2390
# volume_efficiency_to_pts       -> MI Score: 0.4266
# adjusted_shot_creation         -> MI Score: 0.3316
# rolling_e_usg_pct_5G           -> MI Score: 0.1853
#
# --- Mutual Info with: hit_15pts ---
# rolling_pts_avg_5G             -> MI Score: 0.6902
# rolling_pts_median_5G          -> MI Score: 0.5298
# rolling_3pm_avg_5G             -> MI Score: 0.1171
# rolling_3pm_median_5G          -> MI Score: 0.1088
# rolling_min_avg_5G             -> MI Score: 0.2528
# rolling_std_pts_5G             -> MI Score: 0.0780
# pts_consistency_score          -> MI Score: 0.1897
# rolling_opp_def_rating_5G      -> MI Score: 0.0000
# rolling_opp_ast_pct_5G         -> MI Score: 0.0000
# rolling_team_off_rating_5G     -> MI Score: 0.0000
# rolling_team_reb_pct_5G        -> MI Score: 0.0073
# rolling_team_ast_pct_5G        -> MI Score: 0.0000
# rolling_opp_reb_pct_5G         -> MI Score: 0.0000
# latest_team_e_off_rating       -> MI Score: 0.0000
# latest_opp_e_def_rating        -> MI Score: 0.0000
# adjusted_pts_proj_def          -> MI Score: 0.6904
# rolling_usg_pct_5G             -> MI Score: 0.3462
# rolling_fg_pct_5G              -> MI Score: 0.0853
# rolling_fg3_pct_5G             -> MI Score: 0.0743
# rolling_fga_5G                 -> MI Score: 0.4851
# delta_pts_vs_rolling           -> MI Score: 0.0235
# delta_min_vs_rolling           -> MI Score: 0.0070
# opp_def_trend_delta            -> MI Score: 0.0089
# adjusted_pts_proj_usg          -> MI Score: 0.6902
# rest_days                      -> MI Score: 0.0075
# is_b2b                         -> MI Score: 0.0000
# team_pace                      -> MI Score: 0.0111
# opp_pace                       -> MI Score: 0.0002
# shots_per_min                  -> MI Score: 0.3304
# pts_per_fga                    -> MI Score: 0.1963
# pts_per_min                    -> MI Score: 0.4339
# pts_to_3pm_ratio               -> MI Score: 0.2895
# pts_trend_slope_5G             -> MI Score: 0.0226
# is_volume_shooter              -> MI Score: 0.2617
# is_trending_up                 -> MI Score: 0.0000
# is_trending_down               -> MI Score: 0.0000
# high_efficiency                -> MI Score: 0.0470
# rolling_ast_pct_5G             -> MI Score: 0.1000
# rolling_oreb_pct_5G            -> MI Score: 0.0314
# rolling_dreb_pct_5G            -> MI Score: 0.0068
# rolling_reb_pct_5G             -> MI Score: 0.0140
# ast_to_poss_ratio              -> MI Score: 0.0325
# usg_to_poss_ratio              -> MI Score: 0.1039
# engagement_index               -> MI Score: 0.2046
# volume_efficiency_ratio        -> MI Score: 0.3921
# starts_as_C                    -> MI Score: 0.0000
# starts_as_G                    -> MI Score: 0.0248
# starts_as_F                    -> MI Score: 0.0101
# is_starter                     -> MI Score: 0.0601
# HOME_AWAY                      -> MI Score: 0.0090
# fg_pct_vs_avg_delta            -> MI Score: 0.0536
# delta_fga_vs_rolling           -> MI Score: 0.1834
# rolling_pts_from_2_5g          -> MI Score: 0.2568
# rolling_pts_from_3_5g          -> MI Score: 0.1102
# rolling_pts_from_ft_5g         -> MI Score: 0.3019
# rolling_looseball_rec_5g       -> MI Score: 0.0173
# rolling_screen_ast_5g          -> MI Score: 0.0229
# touches_to_pts_ratio           -> MI Score: 0.1501
# transition_pts_pct             -> MI Score: 0.2206
# rolling_opp_blocks_5g          -> MI Score: 0.0043
# rolling_opp_steals_5g          -> MI Score: 0.0070
# rolling_opp_fouls_5g           -> MI Score: 0.0012
# volume_times_efficiency        -> MI Score: 0.6902
# usg_min_product                -> MI Score: 0.4891
# scoring_touch_ratio            -> MI Score: 0.2959
# volume_efficiency_to_pts       -> MI Score: 0.5713
# adjusted_shot_creation         -> MI Score: 0.4839
# rolling_e_usg_pct_5G           -> MI Score: 0.3473
#
# --- Mutual Info with: hit_20pts ---
# rolling_pts_avg_5G             -> MI Score: 0.5701
# rolling_pts_median_5G          -> MI Score: 0.4329
# rolling_3pm_avg_5G             -> MI Score: 0.1097
# rolling_3pm_median_5G          -> MI Score: 0.0980
# rolling_min_avg_5G             -> MI Score: 0.1947
# rolling_std_pts_5G             -> MI Score: 0.0603
# pts_consistency_score          -> MI Score: 0.1432
# rolling_opp_def_rating_5G      -> MI Score: 0.0000
# rolling_opp_ast_pct_5G         -> MI Score: 0.0000
# rolling_team_off_rating_5G     -> MI Score: 0.0000
# rolling_team_reb_pct_5G        -> MI Score: 0.0000
# rolling_team_ast_pct_5G        -> MI Score: 0.0000
# rolling_opp_reb_pct_5G         -> MI Score: 0.0000
# latest_team_e_off_rating       -> MI Score: 0.0000
# latest_opp_e_def_rating        -> MI Score: 0.0000
# adjusted_pts_proj_def          -> MI Score: 0.5703
# rolling_usg_pct_5G             -> MI Score: 0.3306
# rolling_fg_pct_5G              -> MI Score: 0.0688
# rolling_fg3_pct_5G             -> MI Score: 0.0761
# rolling_fga_5G                 -> MI Score: 0.4019
# delta_pts_vs_rolling           -> MI Score: 0.0158
# delta_min_vs_rolling           -> MI Score: 0.0002
# opp_def_trend_delta            -> MI Score: 0.0000
# adjusted_pts_proj_usg          -> MI Score: 0.5701
# rest_days                      -> MI Score: 0.0072
# is_b2b                         -> MI Score: 0.0000
# team_pace                      -> MI Score: 0.0060
# opp_pace                       -> MI Score: 0.0000
# shots_per_min                  -> MI Score: 0.3136
# pts_per_fga                    -> MI Score: 0.1468
# pts_per_min                    -> MI Score: 0.3970
# pts_to_3pm_ratio               -> MI Score: 0.2087
# pts_trend_slope_5G             -> MI Score: 0.0183
# is_volume_shooter              -> MI Score: 0.3265
# is_trending_up                 -> MI Score: 0.0000
# is_trending_down               -> MI Score: 0.0000
# high_efficiency                -> MI Score: 0.0385
# rolling_ast_pct_5G             -> MI Score: 0.1251
# rolling_oreb_pct_5G            -> MI Score: 0.0390
# rolling_dreb_pct_5G            -> MI Score: 0.0061
# rolling_reb_pct_5G             -> MI Score: 0.0140
# ast_to_poss_ratio              -> MI Score: 0.0538
# usg_to_poss_ratio              -> MI Score: 0.1235
# engagement_index               -> MI Score: 0.2200
# volume_efficiency_ratio        -> MI Score: 0.3649
# starts_as_C                    -> MI Score: 0.0000
# starts_as_G                    -> MI Score: 0.0396
# starts_as_F                    -> MI Score: 0.0000
# is_starter                     -> MI Score: 0.0556
# HOME_AWAY                      -> MI Score: 0.0006
# fg_pct_vs_avg_delta            -> MI Score: 0.0283
# delta_fga_vs_rolling           -> MI Score: 0.1398
# rolling_pts_from_2_5g          -> MI Score: 0.2222
# rolling_pts_from_3_5g          -> MI Score: 0.1022
# rolling_pts_from_ft_5g         -> MI Score: 0.2713
# rolling_looseball_rec_5g       -> MI Score: 0.0121
# rolling_screen_ast_5g          -> MI Score: 0.0261
# touches_to_pts_ratio           -> MI Score: 0.1050
# transition_pts_pct             -> MI Score: 0.1365
# rolling_opp_blocks_5g          -> MI Score: 0.0033
# rolling_opp_steals_5g          -> MI Score: 0.0024
# rolling_opp_fouls_5g           -> MI Score: 0.0000
# volume_times_efficiency        -> MI Score: 0.5701
# usg_min_product                -> MI Score: 0.4052
# scoring_touch_ratio            -> MI Score: 0.2559
# volume_efficiency_to_pts       -> MI Score: 0.4814
# adjusted_shot_creation         -> MI Score: 0.3999
# rolling_e_usg_pct_5G           -> MI Score: 0.3249
#
# --- Mutual Info with: hit_25pts ---
# rolling_pts_avg_5G             -> MI Score: 0.3594
# rolling_pts_median_5G          -> MI Score: 0.2656
# rolling_3pm_avg_5G             -> MI Score: 0.0669
# rolling_3pm_median_5G          -> MI Score: 0.0590
# rolling_min_avg_5G             -> MI Score: 0.1080
# rolling_std_pts_5G             -> MI Score: 0.0436
# pts_consistency_score          -> MI Score: 0.0699
# rolling_opp_def_rating_5G      -> MI Score: 0.0000
# rolling_opp_ast_pct_5G         -> MI Score: 0.0000
# rolling_team_off_rating_5G     -> MI Score: 0.0000
# rolling_team_reb_pct_5G        -> MI Score: 0.0000
# rolling_team_ast_pct_5G        -> MI Score: 0.0000
# rolling_opp_reb_pct_5G         -> MI Score: 0.0007
# latest_team_e_off_rating       -> MI Score: 0.0000
# latest_opp_e_def_rating        -> MI Score: 0.0000
# adjusted_pts_proj_def          -> MI Score: 0.3596
# rolling_usg_pct_5G             -> MI Score: 0.2079
# rolling_fg_pct_5G              -> MI Score: 0.0427
# rolling_fg3_pct_5G             -> MI Score: 0.0418
# rolling_fga_5G                 -> MI Score: 0.2386
# delta_pts_vs_rolling           -> MI Score: 0.0140
# delta_min_vs_rolling           -> MI Score: 0.0012
# opp_def_trend_delta            -> MI Score: 0.0000
# adjusted_pts_proj_usg          -> MI Score: 0.3594
# rest_days                      -> MI Score: 0.0000
# is_b2b                         -> MI Score: 0.0073
# team_pace                      -> MI Score: 0.0141
# opp_pace                       -> MI Score: 0.0015
# shots_per_min                  -> MI Score: 0.1950
# pts_per_fga                    -> MI Score: 0.0680
# pts_per_min                    -> MI Score: 0.2644
# pts_to_3pm_ratio               -> MI Score: 0.1060
# pts_trend_slope_5G             -> MI Score: 0.0117
# is_volume_shooter              -> MI Score: 0.1765
# is_trending_up                 -> MI Score: 0.0000
# is_trending_down               -> MI Score: 0.0000
# high_efficiency                -> MI Score: 0.0319
# rolling_ast_pct_5G             -> MI Score: 0.0862
# rolling_oreb_pct_5G            -> MI Score: 0.0323
# rolling_dreb_pct_5G            -> MI Score: 0.0057
# rolling_reb_pct_5G             -> MI Score: 0.0032
# ast_to_poss_ratio              -> MI Score: 0.0408
# usg_to_poss_ratio              -> MI Score: 0.0896
# engagement_index               -> MI Score: 0.1433
# volume_efficiency_ratio        -> MI Score: 0.2426
# starts_as_C                    -> MI Score: 0.0072
# starts_as_G                    -> MI Score: 0.0189
# starts_as_F                    -> MI Score: 0.0000
# is_starter                     -> MI Score: 0.0251
# HOME_AWAY                      -> MI Score: 0.0026
# fg_pct_vs_avg_delta            -> MI Score: 0.0146
# delta_fga_vs_rolling           -> MI Score: 0.0678
# rolling_pts_from_2_5g          -> MI Score: 0.1380
# rolling_pts_from_3_5g          -> MI Score: 0.0678
# rolling_pts_from_ft_5g         -> MI Score: 0.1806
# rolling_looseball_rec_5g       -> MI Score: 0.0047
# rolling_screen_ast_5g          -> MI Score: 0.0173
# touches_to_pts_ratio           -> MI Score: 0.0563
# transition_pts_pct             -> MI Score: 0.0668
# rolling_opp_blocks_5g          -> MI Score: 0.0000
# rolling_opp_steals_5g          -> MI Score: 0.0057
# rolling_opp_fouls_5g           -> MI Score: 0.0000
# volume_times_efficiency        -> MI Score: 0.3594
# usg_min_product                -> MI Score: 0.2420
# scoring_touch_ratio            -> MI Score: 0.1659
# volume_efficiency_to_pts       -> MI Score: 0.3101
# adjusted_shot_creation         -> MI Score: 0.2438
# rolling_e_usg_pct_5G           -> MI Score: 0.2040

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

X = features_df[important_features].fillna(0)
y = features_df['hit_15pts']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model = LogisticRegression(max_iter=1500)
model.fit(X_train, y_train)
preds = model.predict(X_test)

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       813
#            1       0.98      0.98      0.98       637
#
#     accuracy                           0.98      1450
#    macro avg       0.98      0.98      0.98      1450
# weighted avg       0.98      0.98      0.98      1450
# C:\Users\MakerPC\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("dark_background")
plt.rcParams.update({'figure.autolayout': True})

importance = model.coef_[0]

# Sort importance + features together, descending
important_features = np.array(important_features)
sorted_idx = np.argsort(importance)
importance = importance[sorted_idx]
important_features = important_features[sorted_idx]

fig, ax = plt.subplots(figsize=(16, 8))
bars = ax.barh(important_features, importance)

# Apply gradient to Y-axis labels
cmap = plt.get_cmap('tab20')
num_labels = len(important_features)
colors = [cmap(i / num_labels) for i in range(num_labels)]

# Set each tick label's color individually
ax.set_yticks(np.arange(len(important_features)))
ax.set_yticklabels(important_features)
for label, color in zip(ax.get_yticklabels(), colors):
    label.set_color(color)
    label.set_fontsize(8)

plt.title('Logistic Regression Feature Importance')
plt.xlabel('Coefficient')
plt.show()
